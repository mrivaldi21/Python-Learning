# %%
#Python If ... Else
#Python Conditions and If statements
# Equals: a == b
# Not Equals: a != b
# Less than: a < b
# Less than or equal to: a <= b
# Greater than: a > b
# Greater than or equal to: a >= b

#Example
a = 33
b = 200
if b > a:
  print("b is greater than a")

  #Elif
a = 33
b= 33
if b > a:
   print("b is greather than a")
elif a ==b:
  print("b is equals with a")

#Else
a = 200
b = 33
if b > a:
  print("b is greather tan a")
elif a == b:
  print("a is equels with b")
else:
  print("a is greather than b")

#Short Hand If
if a > b: print("a is greather than b")

#Short Hand If ... Else
a = 2
b = 300
print("A") if a > b else print("B")
#Other example
a = 300
b = 300
print("A") if a > b else print("=") if a == b else print("b")

#And
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both condition is True")

#Or
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least ine of the condition is True")

#Not
a = 33
b = 200
if not a > b:
  print("a is Not greather than B")

#Nested IF
x = 41
if x > 10:
  print ("Above ten,")
  if x > 20:
    print("and also above 20")
  else:
    print("but not above 20")

#The pass Statement
# if statements cannot be empty, but if you for some reason have an if statement with no content, put in the pass statement to avoid getting an error.
a = 33
b = 200
if b> a:
  pass
# Out:
# b is greater than a
# b is equals with a
# a is greather than b
# a is greather than b
# B
# =
# Both condition is True
# At least ine of the condition is True
# a is Not greather than B
# Above ten,
# and also above 20

# %%
#Python While Loops
